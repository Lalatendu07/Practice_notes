# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\user\Documents\sportsref_download.xlsx')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
c=pd.read_excel(r'C:\Users\user\Documents\lala.xlsx', header=None ,names=['A','b','d'] )

# %%
c
# Out:
#         A      b   d
# 0    sdsd    fgf NaN
# 1     dsf  dffdf NaN
# 2  fdffdf    dfs NaN
# 3  fdffdf     df NaN
# 4      df     df NaN
# 5      df     df NaN

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.head(7)
# Out:
#    Rk         Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...    FT%  ORB  \
# 0   1     Quincy Acy  PF   24  NYK  68  22  1287  152  331  ...  0.784   79
# 1   2   Jordan Adams  SG   20  MEM  30   0   248   35   86  ...  0.609    9
# 2   3   Steven Adams   C   21  OKC  70  67  1771  217  399  ...  0.502  199
# 3   4    Jeff Adrien  PF   28  MIN  17   0   215   19   44  ...  0.579   23
# 4   5  Arron Afflalo  SG   29  TOT  78  72  2502  375  884  ...  0.843   27
# 5   5  Arron Afflalo  SG   29  DEN  53  53  1750  281  657  ...  0.841   21
# 6   5  Arron Afflalo  SG   29  POR  25  19   752   94  227  ...  0.851    6
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  222  301   68   27   22   60  147   398
# 1   19   28   16   16    7   14   24    94
# 2  324  523   66   38   86   99  222   537
# 3   54   77   15    4    9    9   30    60
# 4  220  247  129   41    7  116  167  1035
# 5  159  180  101   32    5   83  108   771
# 6   61   67   28    9    2   33   59   264
#
# ...

# %%
df.tail(7)
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 493  385       Austin Rivers     PG   22  LAC  41   2   791  117  274  ...
# 494  386      Andre Roberson     SG   23  OKC  67  65  1286   92  201  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# 493  0.582   15   69   84   68   30    7   35   81  291
# 494  0.479   60  195  255   70   53   29   46  141  228
# 495  0.892   13   96  109  162   33    6   57   75  480
# 496  0.667   15   24   39   11    6    1   11   15   73
# 497  0.750    4   10   14    3    3    0    3    5   29
# ...

# %%
a=pd.read_csv('https://raw.githubusercontent.com/sudh9931/data/main/haberman.csv')

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js['user'][0]
# Out:
# {'login': 'pepelovesvim',
#  'id': 26889541,
#  'node_id': 'MDQ6VXNlcjI2ODg5NTQx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/26889541?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pepelovesvim',
#  'html_url': 'https://github.com/pepelovesvim',
#  'followers_url': 'https://api.github.com/users/pepelovesvim/followers',
#  'following_url': 'https://api.github.com/users/pepelovesvim/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/pepelovesvim/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/pepelovesvim/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/pepelovesvim/subscriptions',
#  'organizations_url': 'https://api.github.com/users/pepelovesvim/orgs',
#  'repos_url': 'https://api.github.com/users/pepelovesvim/repos',
#  'events_url': 'https://api.github.com/users/pepelovesvim/events{/privacy}',
# ...

# %%
df.to_json('lala.json')

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
js['state']
# Out:
# 0     open
# 1     open
# 2     open
# 3     open
# 4     open
# 5     open
# 6     open
# 7     open
# 8     open
# 9     open
# 10    open
# 11    open
# 12    open
# 13    open
# 14    open
# 15    open
# 16    open
# 17    open
# 18    open
# 19    open
# 20    open
# 21    open
# 22    open
# 23    open
# 24    open
# 25    open
# 26    open
# 27    open
# 28    open
# 29    open
# Name: state, dtype: object

# %%
js.dtypes
# Out:
# url                                      object
# repository_url                           object
# labels_url                               object
# comments_url                             object
# events_url                               object
# html_url                                 object
# id                                        int64
# node_id                                  object
# number                                    int64
# title                                    object
# user                                     object
# labels                                   object
# state                                    object
# locked                                     bool
# assignee                                 object
# assignees                                object
# milestone                                object
# comments                                  int64
# created_at                  datetime64[ns, UTC]
# updated_at                  datetime64[ns, UTC]
# ...

# %%
c[['A','b']]
# Out:
#         A      b
# 0    sdsd    fgf
# 1     dsf  dffdf
# 2  fdffdf    dfs
# 3  fdffdf     df
# 4      df     df
# 5      df     df

# %%
type(js['state'])
# Out:
# pandas.core.series.Series

# %%
type([['state']])
# Out:
# list

# %%
js.dtypes == 'object'
# Out:
# url                          True
# repository_url               True
# labels_url                   True
# comments_url                 True
# events_url                   True
# html_url                     True
# id                          False
# node_id                      True
# number                      False
# title                        True
# user                         True
# labels                       True
# state                        True
# locked                      False
# assignee                     True
# assignees                    True
# milestone                    True
# comments                    False
# created_at                  False
# updated_at                  False
# closed_at                   False
# author_association           True
# active_lock_reason          False
# body                         True
# reactions                    True
# timeline_url                 True
# performed_via_github_app    False
# ...

# %%
js.dtypes[js.dtypes=='object']
# Out:
# url                   object
# repository_url        object
# labels_url            object
# comments_url          object
# events_url            object
# html_url              object
# node_id               object
# title                 object
# user                  object
# labels                object
# state                 object
# assignee              object
# assignees             object
# milestone             object
# author_association    object
# body                  object
# reactions             object
# timeline_url          object
# pull_request          object
# dtype: object

# %%
js[js.dtypes[js.dtypes=='object'].index].describe()
# Out:
#                                                       url  \
# count                                                  30
# unique                                                 30
# top     https://api.github.com/repos/pandas-dev/pandas...
# freq                                                    1
#
#                                         repository_url  \
# count                                               30
# unique                                               1
# top     https://api.github.com/repos/pandas-dev/pandas
# freq                                                30
#
#                                                labels_url  \
# count                                                  30
# unique                                                 30
# top     https://api.github.com/repos/pandas-dev/pandas...
# freq                                                    1
#
#                                              comments_url  \
# ...

# %%
js.describe()
# Out:
#                  id        number   comments  active_lock_reason  \
# count  3.000000e+01     30.000000  30.000000                 0.0
# mean   1.336661e+09  48049.233333   2.166667                 NaN
# std    8.670130e+05     13.029630   3.040909                 NaN
# min    1.335201e+09  48027.000000   0.000000                 NaN
# 25%    1.336069e+09  48038.250000   0.000000                 NaN
# 50%    1.336579e+09  48050.500000   1.000000                 NaN
# 75%    1.337492e+09  48060.750000   3.000000                 NaN
# max    1.337895e+09  48068.000000  15.000000                 NaN
#
#        performed_via_github_app  state_reason  draft
# count                       0.0           0.0   15.0
# mean                        NaN           NaN    0.0
# std                         NaN           NaN    0.0
# min                         NaN           NaN    0.0
# 25%                         NaN           NaN    0.0
# 50%                         NaN           NaN    0.0
# ...

# %%
js[js.dtypes[js.dtypes=='float64'].index].describe()
# Out:
#        active_lock_reason  performed_via_github_app  state_reason  draft
# count                 0.0                       0.0           0.0   15.0
# mean                  NaN                       NaN           NaN    0.0
# std                   NaN                       NaN           NaN    0.0
# min                   NaN                       NaN           NaN    0.0
# 25%                   NaN                       NaN           NaN    0.0
# 50%                   NaN                       NaN           NaN    0.0
# 75%                   NaN                       NaN           NaN    0.0
# max                   NaN                       NaN           NaN    0.0

# %%
js['id'][1:6:2]
# Out:
# 1    1337810498
# 3    1337622557
# 5    1337572051
# Name: id, dtype: int64

# %%
js['name']='lala'

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.describe()
# Out:
#                  id        number   comments  active_lock_reason  \
# count  3.000000e+01     30.000000  30.000000                 0.0
# mean   1.336661e+09  48049.233333   2.166667                 NaN
# std    8.670130e+05     13.029630   3.040909                 NaN
# min    1.335201e+09  48027.000000   0.000000                 NaN
# 25%    1.336069e+09  48038.250000   0.000000                 NaN
# 50%    1.336579e+09  48050.500000   1.000000                 NaN
# 75%    1.337492e+09  48060.750000   3.000000                 NaN
# max    1.337895e+09  48068.000000  15.000000                 NaN
#
#        performed_via_github_app  state_reason  draft
# count                       0.0           0.0   15.0
# mean                        NaN           NaN    0.0
# std                         NaN           NaN    0.0
# min                         NaN           NaN    0.0
# 25%                         NaN           NaN    0.0
# 50%                         NaN           NaN    0.0
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request',
#        'name'],
#       dtype='object')

# %%
js[js['number']==max(js['number'])]['id']
# Out:
# 0    1337895394
# Name: id, dtype: int64

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
len(df['Age']==21)
# Out:
# 500

# %%
df[df['Age']==21]['Player']
# Out:
# 2                  Steven Adams
# 19                Kyle Anderson
# 48                 Bradley Beal
# 52              Anthony Bennett
# 94     Kentavious Caldwell-Pope
# 147               Anthony Davis
# 160           Spencer Dinwiddie
# 171              Andre Drummond
# 253            Maurice Harkless
# 301               Grant Jerrett
# 302               Grant Jerrett
# 303               Grant Jerrett
# 322              Sergey Karasev
# 324      Michael Kidd-Gilchrist
# 346                    Alex Len
# 374              K.J. McDaniels
# 375              K.J. McDaniels
# 376              K.J. McDaniels
# 382                Ben McLemore
# 435             Johnny O'Bryant
# 464             Otto Porter Jr.
# 496          Glenn Robinson III
# 497          Glenn Robinson III
# 498          Glenn Robinson III
# Name: Player, dtype: object

# %%
df[(df['Age'] > 30) & (df['G'] > 20)]
# Out:
#       Rk            Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...    FT%  \
# 12    11        Tony Allen  SG   33  MEM  63  41  1648  225  455  ...  0.627
# 14    13      Lou Amundson  PF   32  TOT  53  35   937  109  255  ...  0.471
# 16    13      Lou Amundson  PF   32  NYK  41  35   858  105  243  ...  0.463
# 17    14    Chris Andersen   C   36  MIA  60  20  1132  120  207  ...  0.667
# 18    15     Alan Anderson  SG   32  BRK  74  19  1744  195  440  ...  0.812
# ..   ...               ...  ..  ...  ...  ..  ..   ...  ...  ...  ...    ...
# 478  376   Tayshaun Prince  SF   34  MEM  26   9   628   75  183  ...  0.833
# 480  376   Tayshaun Prince  SF   34  DET  23   7   571   69  160  ...  0.655
# 483  379  Shavlik Randolph  PF   31  TOT  21   0   126    9   35  ...  0.500
# 486  380     Zach Randolph  PF   33  MEM  71  71  2304  454  932  ...  0.765
# 490  384      Luke Ridnour  PG   33  ORL  47   0   683   75  176  ...  0.857
#
# ...

# %%
df['date']=pd.to_datetime(df['PF'])

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# ...

# %%
df['year']=df['date'].dt.year

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
# ...

# %%
df[['date','year','Rk','Age']]
# Out:
#                              date  year   Rk  Age
# 0   1970-01-01 00:00:00.000000147  1970    1   24
# 1   1970-01-01 00:00:00.000000024  1970    2   20
# 2   1970-01-01 00:00:00.000000222  1970    3   21
# 3   1970-01-01 00:00:00.000000030  1970    4   28
# 4   1970-01-01 00:00:00.000000167  1970    5   29
# ..                            ...   ...  ...  ...
# 495 1970-01-01 00:00:00.000000075  1970  387   29
# 496 1970-01-01 00:00:00.000000015  1970  388   21
# 497 1970-01-01 00:00:00.000000005  1970  388   21
# 498 1970-01-01 00:00:00.000000010  1970  388   21
# 499 1970-01-01 00:00:00.000000076  1970  389   30
#
# [500 rows x 4 columns]

# %%
df['Rk'].value_counts()
# Out:
# 245    4
# 376    4
# 114    4
# 341    4
# 373    4
#       ..
# 138    1
# 137    1
# 136    1
# 135    1
# 389    1
# Name: Rk, Length: 389, dtype: int64

# %%
df['time'] = df['G'] + df['Rk']

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
# ...

# %%
df.drop('date', axis=1 , inplace=True)

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 1      2        Jordan Adams     SG   20  MEM  30   0   248   35   86  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS  year  time
# ...

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#       Rk              Player    Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1          Quincy Acy     PF   24  NYK  68  22  1287  152  331  ...
# 2      3        Steven Adams      C   21  OKC  70  67  1771  217  399  ...
# 3      4         Jeff Adrien     PF   28  MIN  17   0   215   19   44  ...
# 4      5       Arron Afflalo     SG   29  TOT  78  72  2502  375  884  ...
# 5      5       Arron Afflalo     SG   29  DEN  53  53  1750  281  657  ...
# ..   ...                 ...    ...  ...  ...  ..  ..   ...  ...  ...  ...
# 495  387       Brian Roberts     PG   29  CHO  72  10  1330  176  452  ...
# 496  388  Glenn Robinson III  SG-SF   21  TOT  35   1   261   26   67  ...
# 497  388  Glenn Robinson III     SG   21  MIN  25   0   108    8   24  ...
# 498  388  Glenn Robinson III     SF   21  PHI  10   1   153   18   43  ...
# 499  389       Nate Robinson     PG   30  TOT  42   1   591   88  255  ...
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS  year  time
# ...

# %%
df.loc[[2,15]]
# Out:
#     Rk        Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  DRB  TRB  \
# 2    3  Steven Adams   C   21  OKC  70  67  1771  217  399  ...  324  523
# 15  13  Lou Amundson  PF   32  CLE  12   0    79    4   12  ...   15   20
#
#     AST  STL  BLK  TOV   PF  PTS  year  time
# 2    66   38   86   99  222  537  1970    73
# 15    5    1    0    5   11   11  1970    25
#
# [2 rows x 32 columns]

# %%
df.loc[3:15:2]
# Out:
#     Rk           Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  DRB  TRB  \
# 3    4      Jeff Adrien  PF   28  MIN  17   0   215   19   44  ...   54   77
# 5    5    Arron Afflalo  SG   29  DEN  53  53  1750  281  657  ...  159  180
# 7    6    Alexis Ajinça   C   26  NOP  68   8   957  181  329  ...  211  315
# 9    8     Cole Aldrich   C   26  NYK  61  16   976  144  301  ...  237  338
# 11  10      Lavoy Allen   C   25  IND  63   0  1070  141  299  ...  200  323
# 13  12  Al-Farouq Aminu  SF   24  DAL  74   3  1366  147  357  ...  228  342
# 15  13     Lou Amundson  PF   32  CLE  12   0    79    4   12  ...   15   20
#
#     AST  STL  BLK  TOV   PF  PTS  year  time
# 3    15    4    9    9   30   60  1970    21
# 5   101   32    5   83  108  771  1970    58
# 7    47   21   51   69  151  443  1970    74
# 9    75   37   65   59  122  338  1970    69
# 11   73   15   42   40  102  315  1970    73
# 13   59   70   62   55  137  412  1970    86
# ...

# %%
df.loc[0:4,['Rk','Player','Pos']]
# Out:
#    Rk         Player Pos
# 0   1     Quincy Acy  PF
# 2   3   Steven Adams   C
# 3   4    Jeff Adrien  PF
# 4   5  Arron Afflalo  SG

# %%
df.iloc[0:4,0:3]
# Out:
#    Rk         Player Pos
# 0   1     Quincy Acy  PF
# 2   3   Steven Adams   C
# 3   4    Jeff Adrien  PF
# 4   5  Arron Afflalo  SG

# %%
js.dropna()
# Out:
# Empty DataFrame
# Columns: [url, repository_url, labels_url, comments_url, events_url, html_url, id, node_id, number, title, user, labels, state, locked, assignee, assignees, milestone, comments, created_at, updated_at, closed_at, author_association, active_lock_reason, body, reactions, timeline_url, performed_via_github_app, state_reason, draft, pull_request, name]
# Index: []
#
# [0 rows x 31 columns]

# %%
js.dropna(axis=1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
c.dropna(thresh=3)
# Out:
# Empty DataFrame
# Columns: [A, b, d]
# Index: []

# %%
c
# Out:
#         A      b   d
# 0    sdsd    fgf NaN
# 1     dsf  dffdf NaN
# 2  fdffdf    dfs NaN
# 3  fdffdf     df NaN
# 4      df     df NaN
# 5      df     df NaN

# %%
c.fillna(value=7)
# Out:
#         A      b    d
# 0    sdsd    fgf  7.0
# 1     dsf  dffdf  7.0
# 2  fdffdf    dfs  7.0
# 3  fdffdf     df  7.0
# 4      df     df  7.0
# 5      df     df  7.0

# %%
c.fillna(value=df['Rk'].mean())
# Out:
#         A      b           d
# 0    sdsd    fgf  201.362725
# 1     dsf  dffdf  201.362725
# 2  fdffdf    dfs  201.362725
# 3  fdffdf     df  201.362725
# 4      df     df  201.362725
# 5      df     df  201.362725

# %%
df.groupby('Age')['G'].mean()
# Out:
# Age
# 19    47.800000
# 20    45.000000
# 21    45.458333
# 22    40.820513
# 23    34.985075
# 24    38.509434
# 25    50.710526
# 26    49.047619
# 27    47.761905
# 28    49.588235
# 29    61.846154
# 30    52.043478
# 31    45.800000
# 32    48.722222
# 33    47.769231
# 34    55.200000
# 35    35.500000
# 36    57.250000
# 37    44.428571
# 38    49.875000
# Name: G, dtype: float64

# %%
df.Age
# Out:
# 0      24
# 2      21
# 3      28
# 4      29
# 5      29
#        ..
# 495    29
# 496    21
# 497    21
# 498    21
# 499    30
# Name: Age, Length: 499, dtype: int64

# %%
df.dtypes
# Out:
# Rk          int64
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP          int64
# FG          int64
# FGA         int64
# FG%       float64
# 3P          int64
# 3PA         int64
# 3P%       float64
# 2P          int64
# 2PA         int64
# 2P%       float64
# eFG%      float64
# FT          int64
# FTA         int64
# FT%       float64
# ORB         int64
# DRB         int64
# TRB         int64
# AST         int64
# STL         int64
# BLK         int64
# TOV         int64
# PF          int64
# PTS         int64
# year        int64
# time        int64
# dtype: object

# %%
df.year.astype(int)
# Out:
# 0      1970
# 2      1970
# 3      1970
# 4      1970
# 5      1970
#        ...
# 495    1970
# 496    1970
# 497    1970
# 498    1970
# 499    1970
# Name: year, Length: 499, dtype: int32

# %%
df.year.str.replace(',','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 df.year.str.replace(',','').astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %%
df.groupby('Age')['G'].sum()
