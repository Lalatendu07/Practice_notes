# %%
import pandas as pd

# %%
data={'k1': ['lala','hhsf','lizy','code'] ,
   'k2':['ineuron','python','pandas','data'],
   'k3': ['mongodb','opp','mysql','cloud'], 
   'k4':[100,300,500,700]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      k1       k2       k3   k4
# 0  lala  ineuron  mongodb  100
# 1  hhsf   python      opp  300
# 2  lizy   pandas    mysql  500
# 3  code     data    cloud  700

# %%
df.loc[1:2,['k1','k2']]
# Out:
#      k1      k2
# 1  hhsf  python
# 2  lizy  pandas

# %%
df.iloc[0:3,1:3]
# Out:
#         k2       k3
# 0  ineuron  mongodb
# 1   python      opp
# 2   pandas    mysql

# %%
data2={'age':[21,34,54,33],
       'year':[1990,2000,2015,2022],
       'passwd':['xyz','pqr','abc','mno'],
       'id':['p','q','r','s']}

# %%
ds=pd.DataFrame(data2)

# %%
ds
# Out:
#    age  year passwd id
# 0   21  1990    xyz  p
# 1   34  2000    pqr  q
# 2   54  2015    abc  r
# 3   33  2022    mno  s

# %%
pd.concat([df,ds])
# Out:
#      k1       k2       k3     k4   age    year passwd   id
# 0  lala  ineuron  mongodb  100.0   NaN     NaN    NaN  NaN
# 1  hhsf   python      opp  300.0   NaN     NaN    NaN  NaN
# 2  lizy   pandas    mysql  500.0   NaN     NaN    NaN  NaN
# 3  code     data    cloud  700.0   NaN     NaN    NaN  NaN
# 0   NaN      NaN      NaN    NaN  21.0  1990.0    xyz    p
# 1   NaN      NaN      NaN    NaN  34.0  2000.0    pqr    q
# 2   NaN      NaN      NaN    NaN  54.0  2015.0    abc    r
# 3   NaN      NaN      NaN    NaN  33.0  2022.0    mno    s

# %%
pd.concat([ds,df],axis=1)
# Out:
#    age  year passwd id    k1       k2       k3   k4
# 0   21  1990    xyz  p  lala  ineuron  mongodb  100
# 1   34  2000    pqr  q  hhsf   python      opp  300
# 2   54  2015    abc  r  lizy   pandas    mysql  500
# 3   33  2022    mno  s  code     data    cloud  700

# %%
d={'a':['apple','ball','cat'],
  'b':['good','bad','dad'],
  'c':['c1','c2','c3']}

# %%
r={'a':['a1','b2','c3'],
  'b':['m','n','o'],
  'c':['x','y','z']}

# %%
a=pd.DataFrame(d)

# %%
b=pd.DataFrame(r)

# %%
a
# Out:
#        a     b   c
# 0  apple  good  c1
# 1   ball   bad  c2
# 2    cat   dad  c3

# %%
b
# Out:
#     a  b  c
# 0  a1  m  x
# 1  b2  n  y
# 2  c3  o  z

# %%
pd.concat([a,b])
# Out:
#        a     b   c
# 0  apple  good  c1
# 1   ball   bad  c2
# 2    cat   dad  c3
# 0     a1     m   x
# 1     b2     n   y
# 2     c3     o   z

# %%
c={'id':['a1','b1','c1'],
  'a':['dfd','sdd','defded'],
  'd':['wdw','ded','wd']}

# %%
d={'id':['a1','d1','c1'],
  'date':['aug','jan','feb'],
  'year':[2000,2019,2022]}

# %%
e=pd.DataFrame(c)

# %%
e
# Out:
#    id       a    d
# 0  a1     dfd  wdw
# 1  b1     sdd  ded
# 2  c1  defded   wd

# %%
f=pd.DataFrame(d)

# %%
f
# Out:
#    id date  year
# 0  a1  aug  2000
# 1  d1  jan  2019
# 2  c1  feb  2022

# %%
pd.merge(e,f , how='left')
# Out:
#    id       a    d date    year
# 0  a1     dfd  wdw  aug  2000.0
# 1  b1     sdd  ded  NaN     NaN
# 2  c1  defded   wd  feb  2022.0

# %%
pd.merge(e,f ,how='right', on='id')
# Out:
#    id       a    d date  year
# 0  a1     dfd  wdw  aug  2000
# 1  d1     NaN  NaN  jan  2019
# 2  c1  defded   wd  feb  2022

# %%
da={'a':[1,2,3,4],
   'b':[11,22,33,44],
   'c':[111,222,333,444]}

# %%
da1={'a1':[1,2,3,4],
    's':['as','sd','df','gfg'],
    'g':['pypi','js','ana','ps']}

# %%
x=pd.DataFrame(da)

# %%
y=pd.DataFrame(da1,index=['a','b','c','d'])

# %%
x
# Out:
#    a   b    c
# 0  1  11  111
# 1  2  22  222
# 2  3  33  333
# 3  4  44  444

# %%
y
# Out:
#    a1    s     g
# a   1   as  pypi
# b   2   sd    js
# c   3   df   ana
# d   4  gfg    ps

# %%
pd.merge(x,y,left_on='a',right_on='a1')
# Out:
#    a   b    c  a1    s     g
# 0  1  11  111   1   as  pypi
# 1  2  22  222   2   sd    js
# 2  3  33  333   3   df   ana
# 3  4  44  444   4  gfg    ps

# %%
x.join(y)
# Out:
#    a   b    c  a1    s    g
# 0  1  11  111 NaN  NaN  NaN
# 1  2  22  222 NaN  NaN  NaN
# 2  3  33  333 NaN  NaN  NaN
# 3  4  44  444 NaN  NaN  NaN

# %%
x.join(df)
# Out:
#    a   b    c    k1       k2       k3   k4
# 0  1  11  111  lala  ineuron  mongodb  100
# 1  2  22  222  hhsf   python      opp  300
# 2  3  33  333  lizy   pandas    mysql  500
# 3  4  44  444  code     data    cloud  700

# %%
def xyz(a):
    if a>2:
        return'+ve'
    else :
        return'-ve'

# %%
xyz(1)
# Out:
# '-ve'

# %%
x['sign']=x['a'].apply(xyz)

# %%
x
# Out:
#    a   b    c sign
# 0  1  11  111  -ve
# 1  2  22  222  -ve
# 2  3  33  333  +ve
# 3  4  44  444  +ve

# %%
df['ln']=df['k2'].apply(len)

# %%
df
# Out:
#      k1       k2       k3   k4  ln
# 0  lala  ineuron  mongodb  100   7
# 1  hhsf   python      opp  300   6
# 2  lizy   pandas    mysql  500   6
# 3  code     data    cloud  700   4

# %%
x['sq']=x['a'].apply(lambda a : a**2)

# %%
x
# Out:
#    a   b    c sign  sq
# 0  1  11  111  -ve   1
# 1  2  22  222  -ve   4
# 2  3  33  333  +ve   9
# 3  4  44  444  +ve  16
